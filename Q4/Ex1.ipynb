# %%
! pip install opencv-python

# %%
import cv2
import os

# %%
# Function to extract frames from the video
def extract_frames(video_path, output_folder):
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)

    # Check if the video is opened correctly
    if not video_capture.isOpened():
        print("Error: Could not open video.")
        return

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Frame counter
    frame_count = 0

    while True:
        ret, frame = video_capture.read()

        # If the frame is read correctly, ret will be True
        if not ret:
            break
        
        # Save the frame as an image
        frame_filename = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
        cv2.imwrite(frame_filename, frame)

        print(f"Extracting frame {frame_count}")
        frame_count += 1

    # Release the video capture object
    video_capture.release()
    print(f"Extraction complete. {frame_count} frames extracted.")

# %%
video_path = 'video.mp4'  
output_folder = './output'

# %%
extract_frames(video_path, output_folder)
# Out:
# Extracting frame 0
# Extracting frame 1
# Extracting frame 2
# Extracting frame 3
# Extracting frame 4
# Extracting frame 5
# Extracting frame 6
# Extracting frame 7
# Extracting frame 8
# Extracting frame 9
# Extracting frame 10
# Extracting frame 11
# Extracting frame 12
# Extracting frame 13
# Extracting frame 14
# Extracting frame 15
# Extracting frame 16
# Extracting frame 17
# Extracting frame 18
# Extracting frame 19
# Extracting frame 20
# Extracting frame 21
# Extracting frame 22
# Extracting frame 23
# Extracting frame 24
# Extracting frame 25
# Extracting frame 26
# Extracting frame 27
# Extracting frame 28
# Extracting frame 29
# Extracting frame 30
# Extracting frame 31
# Extracting frame 32
# Extracting frame 33
# Extracting frame 34
# Extracting frame 35
# Extracting frame 36
# Extracting frame 37
# Extracting frame 38
# Extracting frame 39
# Extracting frame 40
# Extracting frame 41
# Extracting frame 42
# Extracting frame 43
# Extracting frame 44
# Extracting frame 45
# Extracting frame 46
# Extracting frame 47
# Extracting frame 48
# Extracting frame 49
# Extracting frame 50
# Extracting frame 51
# Extracting frame 52
# Extracting frame 53
# Extracting frame 54
# Extracting frame 55
# Extracting frame 56
# Extracting frame 57
# Extracting frame 58
# Extracting frame 59
# Extracting frame 60
# Extracting frame 61
# Extracting frame 62
# Extracting frame 63
# Extracting frame 64
# Extracting frame 65
# Extracting frame 66
# Extracting frame 67
# Extracting frame 68
# Extracting frame 69
# Extracting frame 70
# Extracting frame 71
# Extracting frame 72
# Extracting frame 73
# Extracting frame 74
# Extracting frame 75
# Extracting frame 76
# Extracting frame 77
# Extracting frame 78
# Extracting frame 79
# Extracting frame 80
# Extracting frame 81
# Extracting frame 82
# Extracting frame 83
# Extracting frame 84
# Extracting frame 85
# Extracting frame 86
# Extracting frame 87
# Extracting frame 88
# Extracting frame 89
# Extracting frame 90
# Extracting frame 91
# Extracting frame 92
# Extracting frame 93
# Extracting frame 94
# Extracting frame 95
# Extracting frame 96
# Extracting frame 97
# Extracting frame 98
# Extracting frame 99
# Extracting frame 100
# Extracting frame 101
# Extracting frame 102
# Extracting frame 103
# Extracting frame 104
# Extracting frame 105
# Extracting frame 106
# Extracting frame 107
# Extracting frame 108
# Extracting frame 109
# Extracting frame 110
# Extracting frame 111
# Extracting frame 112
# Extracting frame 113
# Extracting frame 114
# Extracting frame 115
# Extracting frame 116
# Extracting frame 117
# Extracting frame 118
# Extracting frame 119
# Extracting frame 120
# Extracting frame 121
# Extracting frame 122
# Extracting frame 123
# Extracting frame 124
# Extracting frame 125
# Extracting frame 126
# Extracting frame 127
# Extracting frame 128
# Extracting frame 129
# Extracting frame 130
# Extracting frame 131
# Extracting frame 132
# Extracting frame 133
# Extracting frame 134
# Extracting frame 135
# Extracting frame 136
# Extracting frame 137
# Extracting frame 138
# Extracting frame 139
# Extracting frame 140
# Extracting frame 141
# Extracting frame 142
# Extracting frame 143
# Extracting frame 144
# Extracting frame 145
# Extracting frame 146
# Extracting frame 147
# Extracting frame 148
# Extracting frame 149
# Extracting frame 150
# Extracting frame 151
# Extracting frame 152
# Extracting frame 153
# Extracting frame 154
# Extracting frame 155
# Extracting frame 156
# Extracting frame 157
# Extracting frame 158
# Extracting frame 159
# Extracting frame 160
# Extracting frame 161
# Extracting frame 162
# Extracting frame 163
# Extracting frame 164
# Extracting frame 165
# Extracting frame 166
# Extracting frame 167
# Extracting frame 168
# Extracting frame 169
# Extracting frame 170
# Extracting frame 171
# Extracting frame 172
# Extracting frame 173
# Extracting frame 174
# Extracting frame 175
# Extracting frame 176
# Extracting frame 177
# Extracting frame 178
# Extracting frame 179
# Extracting frame 180
# Extracting frame 181
# Extracting frame 182
# Extracting frame 183
# Extracting frame 184
# Extracting frame 185
# Extracting frame 186
# Extracting frame 187
# Extracting frame 188
# Extracting frame 189
# Extracting frame 190
# Extracting frame 191
# Extracting frame 192
# Extracting frame 193
# Extracting frame 194
# Extracting frame 195
# Extracting frame 196
# Extracting frame 197
# Extracting frame 198
# Extracting frame 199
# Extracting frame 200
# Extracting frame 201
# Extracting frame 202
# Extracting frame 203
# Extracting frame 204
# Extracting frame 205
# Extracting frame 206
# Extracting frame 207
# Extracting frame 208
# Extracting frame 209
# Extracting frame 210
# Extracting frame 211
# Extracting frame 212
# Extracting frame 213
# Extracting frame 214
# Extracting frame 215
# Extracting frame 216
# Extracting frame 217
# Extracting frame 218
# Extracting frame 219
# Extracting frame 220
# Extracting frame 221
# Extracting frame 222
# Extracting frame 223
# Extracting frame 224
# Extracting frame 225
# Extracting frame 226
# Extracting frame 227
# Extracting frame 228
# Extracting frame 229
# Extracting frame 230
# Extracting frame 231
# Extracting frame 232
# Extracting frame 233
# Extracting frame 234
# Extracting frame 235
# Extracting frame 236
# Extracting frame 237
# Extracting frame 238
# Extracting frame 239
# Extracting frame 240
# Extracting frame 241
# Extracting frame 242
# Extracting frame 243
# Extracting frame 244
# Extracting frame 245
# Extracting frame 246
# Extracting frame 247
# Extracting frame 248
# Extracting frame 249
# Extracting frame 250
# Extracting frame 251
# Extracting frame 252
# Extracting frame 253
# Extracting frame 254
# Extracting frame 255
# Extracting frame 256
# Extracting frame 257
# Extracting frame 258
# Extracting frame 259
# Extracting frame 260
# Extracting frame 261
# Extracting frame 262
# Extracting frame 263
# Extracting frame 264
# Extracting frame 265
# Extracting frame 266
# Extracting frame 267
# Extracting frame 268
# Extracting frame 269
# Extracting frame 270
# Extracting frame 271
# Extracting frame 272
# Extracting frame 273
# Extracting frame 274
# Extracting frame 275
# Extracting frame 276
# Extracting frame 277
# Extracting frame 278
# Extracting frame 279
# Extracting frame 280
# Extracting frame 281
# Extracting frame 282
# Extracting frame 283
# Extracting frame 284
# Extracting frame 285
# Extracting frame 286
# Extracting frame 287
# Extracting frame 288
# Extracting frame 289
# Extracting frame 290
# Extracting frame 291
# Extracting frame 292
# Extracting frame 293
# Extracting frame 294
# Extracting frame 295
# Extracting frame 296
# Extracting frame 297
# Extracting frame 298
# Extracting frame 299
# Extracting frame 300
# Extracting frame 301
# Extracting frame 302
# Extracting frame 303
# Extracting frame 304
# Extracting frame 305
# Extracting frame 306
# Extracting frame 307
# Extracting frame 308
# Extracting frame 309
# Extracting frame 310
# Extracting frame 311
# Extracting frame 312
# Extracting frame 313
# Extracting frame 314
# Extracting frame 315
# Extracting frame 316
# Extracting frame 317
# Extracting frame 318
# Extracting frame 319
# Extracting frame 320
# Extracting frame 321
# Extracting frame 322
# Extracting frame 323
# Extracting frame 324
# Extracting frame 325
# Extracting frame 326
# Extracting frame 327
# Extracting frame 328
# Extracting frame 329
# Extraction complete. 330 frames extracted.
