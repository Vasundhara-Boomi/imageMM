# %%
! pip install opencv-python-headless matplotlib

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Load an example image in grayscale
image = cv2.imread('image.png', cv2.IMREAD_GRAYSCALE)
if image is None:
    print("Error: Could not load the image.")
else:
    # Display the original image
    plt.imshow(image, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')
    plt.show()

# %%
# Perform contrast stretching
min_val, max_val = np.min(image), np.max(image)
contrast_factor = -0.1  # Increase this factor to enhance contrast further
contrast_increased = np.clip((image - min_val) * contrast_factor + min_val, 0, 255).astype(np.uint8)
contrast_stretched = cv2.normalize(contrast_increased, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)

# Display contrast-stretched image
plt.imshow(contrast_stretched, cmap='gray')
plt.title('Contrast-Stretched Image')
plt.axis('off')
plt.show()

# %%
# Apply a simple linear filter (Gaussian Blur)
kernel_size = (15, 15)
sigma = 30
filtered_image = cv2.GaussianBlur(image, kernel_size, sigma)

# Display filtered image
plt.imshow(filtered_image, cmap='gray')
plt.title('Filtered Image (Gaussian Blur)')
plt.axis('off')
plt.show()

# %%
# Plot histograms of the original, contrast-stretched, and filtered images
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.hist(image.ravel(), bins=256, range=[0, 256])
plt.title('Histogram of Original Image')

plt.subplot(1, 3, 2)
plt.hist(contrast_stretched.ravel(), bins=256, range=[0, 256])
plt.title('Histogram of Contrast-Stretched Image')

plt.subplot(1, 3, 3)
plt.hist(filtered_image.ravel(), bins=256, range=[0, 256])
plt.title('Histogram of Filtered Image')
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
